# %% [markdown]
# ## 1. Install Dependencies

# %%
import sys
# !{sys.executable} -m pip install --user tensorflow librosa==0.11.0 scikit-learn tqdm numpy pandas matplotlib seaborn --quiet
# Out:
# [notice] A new release of pip available: 22.3.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ## 2. Imports and Setup

# %%
import os
import re
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import librosa
import warnings
warnings.filterwarnings('ignore')

from tqdm import tqdm
from sklearn.metrics import (
    accuracy_score, confusion_matrix,
    ConfusionMatrixDisplay, classification_report, f1_score
)

import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import (
    Input, Conv2D, MaxPooling2D, BatchNormalization,
    Flatten, Dense, Dropout, GlobalAveragePooling2D
)
from keras.optimizers import Adam
from keras.losses import SparseCategoricalCrossentropy
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)
tf.random.set_seed(RANDOM_STATE)

SR      = 22050
N_MELS  = 128
N_FFT   = 2048
HOP_LEN = 512
FMIN    = 20
FMAX    = 8000

N_FRAMES   = 128
HOP_FRAMES = 64
N_CLASSES  = 10
BATCH_SIZE = 32
EPOCHS     = 100

CLASSES = [
    'bus', 'busystreet', 'office', 'openairmarket', 'park',
    'quietstreet', 'restaurant', 'supermarket', 'tube', 'tubestation'
]
CLASS_TO_IDX = {cls: idx for idx, cls in enumerate(CLASSES)}

OUTPUT_DIR = 'output_block2'
os.makedirs(OUTPUT_DIR, exist_ok=True)

print('TensorFlow version:', tf.__version__)
print('Devices available :', tf.config.list_physical_devices())
print(f'CNN input shape per segment: ({N_FRAMES}, {N_MELS}, 1)')
print(f'Segment duration: {N_FRAMES * HOP_LEN / SR:.2f}s')
print(f'Overlap: {HOP_FRAMES * HOP_LEN / SR:.2f}s')
# Out:
# TensorFlow version: 2.21.0
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.
# Devices available : [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# CNN input shape per segment: (128, 128, 1)
# Segment duration: 2.97s
# Overlap: 1.49s

# %% [markdown]
# ## 3. Load Annotations

# %%
df_train = pd.read_csv(os.path.join(OUTPUT_DIR, 'dcase2013_annotations.csv'))
print(f'Train files: {len(df_train)}')
print(df_train['label'].value_counts().sort_index())
# Out:
# Train files: 100
# label
# bus              10
# busystreet       10
# office           10
# openairmarket    10
# park             10
# quietstreet      10
# restaurant       10
# supermarket      10
# tube             10
# tubestation      10
# Name: count, dtype: int64

# %% [markdown]
# ## 4. Spectrogram Extraction and Segmentation

# %%
def preprocess_audio(filepath, sr=SR):
    wav, _ = librosa.load(filepath, sr=sr, mono=True)
    wav = wav / (np.max(np.abs(wav)) + 1e-9)
    return wav


def extract_logmel_spectrogram(wav, sr=SR):
    """
    Extraer espectrograma Log-Mel completo.
    Returns shape: (T_frames, N_MELS) — primer tiempo para facilitar el slicing.
    """
    mel = librosa.feature.melspectrogram(
        y=wav, sr=sr, n_mels=N_MELS,
        n_fft=N_FFT, hop_length=HOP_LEN,
        fmin=FMIN, fmax=FMAX
    )
    log_mel = librosa.power_to_db(mel, ref=np.max)
    return log_mel.T  # (T, N_MELS)


def segment_spectrogram(spec, n_frames=N_FRAMES, hop_frames=HOP_FRAMES):
    """
    Divide un espectrograma en segmentos solapados de longitud fija.
    Returns shape: (N_segments, n_frames, N_MELS)
    """
    segments = []
    T = spec.shape[0]
    for start in range(0, T - n_frames + 1, hop_frames):
        segments.append(spec[start : start + n_frames])
    return np.array(segments)


def build_segment_dataset(df, augment=False, n_augment=3, noise_std=0.005):
    """
    Extrae segmentos de espectrograma para todos los archivos en df.
    Si augment=True, genera n_augment copias con ruido gaussiano por segmento.

        X        (np.ndarray): (N_segments, N_FRAMES, N_MELS, 1)
        y_seg    (np.ndarray): etiquetas a nivel de segmento
        y_file   (np.ndarray): etiquetas a nivel de archivo
        file_idx (np.ndarray): indice de archivo por segmento
    """
    X        = []
    y_seg    = []
    y_file   = []
    file_idx = []

    for i, (_, row) in enumerate(tqdm(df.iterrows(), total=len(df),
                                      desc='Building segment dataset')):
        wav   = preprocess_audio(row['filepath'])
        spec  = extract_logmel_spectrogram(wav)
        segs  = segment_spectrogram(spec)
        label = row['label_idx']

        for seg in segs:
            # Segmento original 
            X.append(seg)
            y_seg.append(label)
            file_idx.append(i)

            # Copias aumentadas 
            if augment:
                for _ in range(n_augment):
                    seg_aug = seg + np.random.normal(0, noise_std, seg.shape)
                    seg_aug = np.clip(seg_aug, seg.min(), seg.max())
                    X.append(seg_aug)
                    y_seg.append(label)
                    file_idx.append(i)

        y_file.append(label)

    X        = np.array(X, dtype=np.float32)[..., np.newaxis]
    y_seg    = np.array(y_seg,    dtype=np.int32)
    y_file   = np.array(y_file,   dtype=np.int32)
    file_idx = np.array(file_idx, dtype=np.int32)

    return X, y_seg, y_file, file_idx


# Test rapido
test_wav  = preprocess_audio(df_train.iloc[0]['filepath'])
test_spec = extract_logmel_spectrogram(test_wav)
test_segs = segment_spectrogram(test_spec)

print(f'Full spectrogram shape : {test_spec.shape}  (T_frames, N_MELS)')
print(f'Segments shape         : {test_segs.shape}  (N_segments, N_FRAMES, N_MELS)')
print(f'Segments per file      : {test_segs.shape[0]}')
# Out:
# Full spectrogram shape : (1292, 128)  (T_frames, N_MELS)
# Segments shape         : (19, 128, 128)  (N_segments, N_FRAMES, N_MELS)
# Segments per file      : 19

# %% [markdown]
# ## 5. Build Full Dataset of Segments

# %%
from sklearn.model_selection import train_test_split

# Split a nivel de archivo 
df_tr, df_val = train_test_split(
    df_train,
    test_size=0.2,
    random_state=RANDOM_STATE,
    stratify=df_train['label_idx']
)

print(f'Train files : {len(df_tr)} — dist: {np.bincount(df_tr["label_idx"].values)}')
print(f'Val files   : {len(df_val)} — dist: {np.bincount(df_val["label_idx"].values)}')

# Extraer segmentos — augment=True solo en train 
print('\nExtracting train segments (with Gaussian noise augmentation)...')
X_tr, y_tr, y_tr_file, file_idx_tr = build_segment_dataset(
    df_tr, augment=True, n_augment=3, noise_std=0.005
)

print('Extracting val segments (no augmentation)...')
X_val, y_val, y_val_file, file_idx_val = build_segment_dataset(
    df_val, augment=False
)

print(f'\nTrain segments : {X_tr.shape}  (~x4 con augmentation)')
print(f'Val segments   : {X_val.shape}')
# Out:
# Train files : 80 — dist: [8 8 8 8 8 8 8 8 8 8]
# Val files   : 20 — dist: [2 2 2 2 2 2 2 2 2 2]
#
# Extracting train segments (with Gaussian noise augmentation)...
# Building segment dataset: 100%|██████████| 80/80 [00:06<00:00, 11.80it/s]
# Extracting val segments (no augmentation)...
# Building segment dataset: 100%|██████████| 20/20 [00:01<00:00, 15.53it/s]
# Train segments : (6080, 128, 128, 1)  (~x4 con augmentation)
# Val segments   : (380, 128, 128, 1)

# %% [markdown]
# ## 6. Normalize Spectrograms

# %%
global_mean = X_tr.mean()
global_std  = X_tr.std()

X_tr  = (X_tr  - global_mean) / (global_std + 1e-9)
X_val = (X_val - global_mean) / (global_std + 1e-9)

np.save(os.path.join(OUTPUT_DIR, 'cnn_global_mean.npy'), global_mean)
np.save(os.path.join(OUTPUT_DIR, 'cnn_global_std.npy'),  global_std)

print(f'Global mean : {global_mean:.4f} | Global std: {global_std:.4f}')
print(f'After norm — X_tr  mean: {X_tr.mean():.4f}, std: {X_tr.std():.4f}')
print(f'After norm — X_val mean: {X_val.mean():.4f}, std: {X_val.std():.4f}')
print(f'Normalization stats saved to {OUTPUT_DIR}/')
# Out:
# Global mean : -39.0170 | Global std: 13.0664
# After norm — X_tr  mean: 0.0000, std: 1.0000
# After norm — X_val mean: -0.1473, std: 0.9798
# Normalization stats saved to output_block2/

# %% [markdown]
# ## 7. CNN Architecture
#
# ### Design decisions:
#
# | Component | Choice | Justification |
# |-----------|--------|---------------|
# | Input shape | (128, 128, 1) | 128 frames × 128 Mel bands, 1 channel (mono) |
# | Conv kernels | (3×3) | Standard for 2D feature extraction; captures local time-frequency patterns |
# | Filters | 32→64→128 | Progressive increase learns increasingly abstract features |
# | BatchNorm | After each Conv | Stabilizes training, acts as regularizer, allows higher learning rates |
# | MaxPooling | (2×2) | Reduces spatial dimensions, adds translation invariance |
# | GlobalAvgPooling | Final spatial layer | More robust than Flatten, reduces parameters, prevents overfitting |
# | Dropout | 0.3 and 0.4 | Prevents overfitting on small dataset |
# | Activation | ReLU | Standard, avoids vanishing gradient |
# | Output | Softmax (10) | Multi-class probability distribution |
# | Optimizer | Adam (lr=1e-3) | Adaptive learning rate, robust default for audio CNNs |

# %%
from keras import regularizers

def build_cnn(input_shape=(N_FRAMES, N_MELS, 1), n_classes=N_CLASSES):
    model = Sequential([
        Input(shape=input_shape),

        # Block 1 
        Conv2D(16, kernel_size=(3, 3), padding='same',
               activation='relu',
               kernel_regularizer=regularizers.l2(0.001)),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.2),

        # Block 2 
        Conv2D(32, kernel_size=(3, 3), padding='same',
               activation='relu',
               kernel_regularizer=regularizers.l2(0.001)),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2, 2)),
        Dropout(0.2),

        # Block 3 
        Conv2D(64, kernel_size=(3, 3), padding='same',
               activation='relu',
               kernel_regularizer=regularizers.l2(0.001)),
        BatchNormalization(),
        GlobalAveragePooling2D(),
        Dropout(0.5),

        # Classifier 
        Dense(64, activation='relu',
              kernel_regularizer=regularizers.l2(0.001)),
        Dropout(0.5),
        Dense(n_classes, activation='softmax')
    ])
    return model

model_cnn = build_cnn()
model_cnn.compile(
    optimizer=Adam(learning_rate=1e-3),
    loss=SparseCategoricalCrossentropy(),
    metrics=['accuracy']
)
model_cnn.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 128, 128, 16)   │           160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 16)   │            64 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 32)     │         4,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32, 32, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 64)             │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         4,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 28,554 (111.54 KB)
#  Trainable params: 28,330 (110.66 KB)
#  Non-trainable params: 224 (896.00 B)

# %% [markdown]
# ## 8. Callbacks

# %%
callbacks = [
    EarlyStopping(
        monitor='val_loss', patience=20,
        restore_best_weights=True, verbose=1
    ),
    ReduceLROnPlateau(
        monitor='val_loss', factor=0.5,
        patience=10, min_lr=1e-6, verbose=1
    )
]
print('Callbacks configured.')
# Out:
# Callbacks configured.

# %% [markdown]
# ## 9. Train the CNN

# %%
from sklearn.model_selection import train_test_split

# Split a nivel de ARCHIVO
df_tr, df_val = train_test_split(
    df_train,
    test_size=0.2,
    random_state=RANDOM_STATE,
    stratify=df_train['label_idx']
)

print(f'Train files : {len(df_tr)} — dist: {np.bincount(df_tr["label_idx"].values)}')
print(f'Val files   : {len(df_val)} — dist: {np.bincount(df_val["label_idx"].values)}')

# Extraer segmentos — augment=True solo en train 
print('\nExtracting train segments (with Gaussian noise augmentation)...')
X_tr, y_tr, y_tr_file, file_idx_tr = build_segment_dataset(
    df_tr, augment=True, n_augment=3, noise_std=0.005
)

print('Extracting val segments (no augmentation)...')
X_val, y_val, y_val_file, file_idx_val = build_segment_dataset(
    df_val, augment=False
)

# Normalizar 
global_mean = X_tr.mean()
global_std  = X_tr.std()

X_tr  = (X_tr  - global_mean) / (global_std + 1e-9)
X_val = (X_val - global_mean) / (global_std + 1e-9)

# Guardar stats para test
np.save('cnn_global_mean_aug.npy', global_mean)
np.save('cnn_global_std_aug.npy',  global_std)

print(f'\nTrain segments : {X_tr.shape}  (original x4 con augmentation)')
print(f'Val segments   : {X_val.shape}')
print(f'Global mean    : {global_mean:.4f} | Global std: {global_std:.4f}')

# ── Entrenar 
history = model_cnn.fit(
    X_tr, y_tr,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(X_val, y_val),
    callbacks=callbacks,
    shuffle=True,
    verbose=1
)
# Out:
# Train files : 80 — dist: [8 8 8 8 8 8 8 8 8 8]
# Val files   : 20 — dist: [2 2 2 2 2 2 2 2 2 2]
#
# Extracting train segments (with Gaussian noise augmentation)...
# Building segment dataset: 100%|██████████| 80/80 [00:06<00:00, 12.44it/s]
# Extracting val segments (no augmentation)...
# Building segment dataset: 100%|██████████| 20/20 [00:01<00:00, 16.87it/s]
# Train segments : (6080, 128, 128, 1)  (original x4 con augmentation)
# Val segments   : (380, 128, 128, 1)
# Global mean    : -39.0170 | Global std: 13.0664
# Epoch 1/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 40s 200ms/step - accuracy: 0.2551 - loss: 2.1832 - val_accuracy: 0.1158 - val_loss: 4.6355 - learning_rate: 0.0010
# Epoch 2/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 194ms/step - accuracy: 0.3640 - loss: 1.8965 - val_accuracy: 0.1000 - val_loss: 8.3684 - learning_rate: 0.0010
# Epoch 3/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 194ms/step - accuracy: 0.4587 - loss: 1.6592 - val_accuracy: 0.1053 - val_loss: 5.3595 - learning_rate: 0.0010
# Epoch 4/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 194ms/step - accuracy: 0.5516 - loss: 1.4251 - val_accuracy: 0.2000 - val_loss: 2.9181 - learning_rate: 0.0010
# Epoch 5/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 39s 207ms/step - accuracy: 0.6132 - loss: 1.2428 - val_accuracy: 0.3342 - val_loss: 2.4963 - learning_rate: 0.0010
# Epoch 6/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 195ms/step - accuracy: 0.6620 - loss: 1.1056 - val_accuracy: 0.3105 - val_loss: 2.7296 - learning_rate: 0.0010
# Epoch 7/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 192ms/step - accuracy: 0.7051 - loss: 0.9987 - val_accuracy: 0.3316 - val_loss: 2.5244 - learning_rate: 0.0010
# Epoch 8/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.7219 - loss: 0.9377 - val_accuracy: 0.4316 - val_loss: 2.4147 - learning_rate: 0.0010
# Epoch 9/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.7447 - loss: 0.8653 - val_accuracy: 0.4421 - val_loss: 2.1279 - learning_rate: 0.0010
# Epoch 10/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.7558 - loss: 0.8360 - val_accuracy: 0.3211 - val_loss: 2.2157 - learning_rate: 0.0010
# Epoch 11/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.7768 - loss: 0.7724 - val_accuracy: 0.4921 - val_loss: 1.9651 - learning_rate: 0.0010
# Epoch 12/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 195ms/step - accuracy: 0.7939 - loss: 0.7365 - val_accuracy: 0.4579 - val_loss: 2.8479 - learning_rate: 0.0010
# Epoch 13/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.8092 - loss: 0.7142 - val_accuracy: 0.4553 - val_loss: 2.1860 - learning_rate: 0.0010
# Epoch 14/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 194ms/step - accuracy: 0.8215 - loss: 0.6689 - val_accuracy: 0.3816 - val_loss: 2.2661 - learning_rate: 0.0010
# Epoch 15/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 194ms/step - accuracy: 0.8209 - loss: 0.6640 - val_accuracy: 0.3474 - val_loss: 2.6137 - learning_rate: 0.0010
# Epoch 16/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 196ms/step - accuracy: 0.8316 - loss: 0.6409 - val_accuracy: 0.5132 - val_loss: 2.2154 - learning_rate: 0.0010
# Epoch 17/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.8403 - loss: 0.6133 - val_accuracy: 0.4105 - val_loss: 2.5119 - learning_rate: 0.0010
# Epoch 18/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.8543 - loss: 0.5817 - val_accuracy: 0.5263 - val_loss: 2.1410 - learning_rate: 0.0010
# Epoch 19/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.8605 - loss: 0.5703 - val_accuracy: 0.6132 - val_loss: 1.8419 - learning_rate: 0.0010
# Epoch 20/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.8651 - loss: 0.5453 - val_accuracy: 0.4947 - val_loss: 2.1164 - learning_rate: 0.0010
# Epoch 21/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.8655 - loss: 0.5432 - val_accuracy: 0.5342 - val_loss: 2.6529 - learning_rate: 0.0010
# Epoch 22/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.8650 - loss: 0.5563 - val_accuracy: 0.4868 - val_loss: 2.6377 - learning_rate: 0.0010
# Epoch 23/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.8758 - loss: 0.5262 - val_accuracy: 0.5658 - val_loss: 2.2328 - learning_rate: 0.0010
# Epoch 24/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 194ms/step - accuracy: 0.8771 - loss: 0.5067 - val_accuracy: 0.4711 - val_loss: 2.1657 - learning_rate: 0.0010
# Epoch 25/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 194ms/step - accuracy: 0.8766 - loss: 0.5108 - val_accuracy: 0.4500 - val_loss: 2.7945 - learning_rate: 0.0010
# Epoch 26/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 194ms/step - accuracy: 0.8808 - loss: 0.5002 - val_accuracy: 0.5658 - val_loss: 2.2474 - learning_rate: 0.0010
# Epoch 27/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.8895 - loss: 0.4752 - val_accuracy: 0.5474 - val_loss: 2.2671 - learning_rate: 0.0010
# Epoch 28/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 194ms/step - accuracy: 0.8941 - loss: 0.4654 - val_accuracy: 0.5079 - val_loss: 2.4028 - learning_rate: 0.0010
# Epoch 29/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step - accuracy: 0.9013 - loss: 0.4473
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.8965 - loss: 0.4609 - val_accuracy: 0.5789 - val_loss: 2.1399 - learning_rate: 0.0010
# Epoch 30/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.9071 - loss: 0.4198 - val_accuracy: 0.5079 - val_loss: 2.1996 - learning_rate: 5.0000e-04
# Epoch 31/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.9178 - loss: 0.4037 - val_accuracy: 0.5789 - val_loss: 2.2296 - learning_rate: 5.0000e-04
# Epoch 32/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 197ms/step - accuracy: 0.9248 - loss: 0.3881 - val_accuracy: 0.5421 - val_loss: 2.0592 - learning_rate: 5.0000e-04
# Epoch 33/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.9215 - loss: 0.3816 - val_accuracy: 0.5053 - val_loss: 2.2883 - learning_rate: 5.0000e-04
# Epoch 34/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.9158 - loss: 0.3973 - val_accuracy: 0.4053 - val_loss: 2.6611 - learning_rate: 5.0000e-04
# Epoch 35/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.9281 - loss: 0.3750 - val_accuracy: 0.5500 - val_loss: 2.3137 - learning_rate: 5.0000e-04
# Epoch 36/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.9262 - loss: 0.3620 - val_accuracy: 0.4763 - val_loss: 2.7696 - learning_rate: 5.0000e-04
# Epoch 37/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.9278 - loss: 0.3648 - val_accuracy: 0.4711 - val_loss: 2.6371 - learning_rate: 5.0000e-04
# Epoch 38/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 193ms/step - accuracy: 0.9225 - loss: 0.3754 - val_accuracy: 0.4842 - val_loss: 2.3418 - learning_rate: 5.0000e-04
# Epoch 39/100
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step - accuracy: 0.9346 - loss: 0.3447
# Epoch 39: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 37s 192ms/step - accuracy: 0.9293 - loss: 0.3570 - val_accuracy: 0.4605 - val_loss: 2.4453 - learning_rate: 5.0000e-04
# Epoch 39: early stopping
# Restoring model weights from the end of the best epoch: 19.

# %% [markdown]
# ## 10. Training Curves

# %%
fig, axes = plt.subplots(1, 2, figsize=(13, 4))

axes[0].plot(history.history['loss'],     label='Train loss',     color='steelblue', linewidth=2)
axes[0].plot(history.history['val_loss'], label='Val loss',       color='tomato',    linewidth=2)
axes[0].set_title('Training and Validation Loss', fontsize=12, fontweight='bold')
axes[0].set_xlabel('Epoch')
axes[0].set_ylabel('Loss')
axes[0].legend()
axes[0].grid(True, alpha=0.3)

axes[1].plot(history.history['accuracy'],     label='Train accuracy', color='steelblue', linewidth=2)
axes[1].plot(history.history['val_accuracy'], label='Val accuracy',   color='tomato',    linewidth=2)
axes[1].set_title('Training and Validation Accuracy', fontsize=12, fontweight='bold')
axes[1].set_xlabel('Epoch')
axes[1].set_ylabel('Accuracy')
axes[1].legend()
axes[1].grid(True, alpha=0.3)

best_epoch = np.argmin(history.history['val_loss'])
for ax in axes:
    ax.axvline(best_epoch, color='green', linestyle='--', linewidth=1.5,
               label=f'Best epoch ({best_epoch+1})')
    ax.legend()

plt.tight_layout()
out_path = os.path.join(OUTPUT_DIR, 'cnn_training_curves.png')
plt.savefig(out_path, dpi=150, bbox_inches='tight')
plt.show()
print(f'Saved: {out_path}')
print(f'Best epoch        : {best_epoch + 1}')
print(f'Best val loss     : {min(history.history["val_loss"]):.4f}')
print(f'Best val accuracy : {max(history.history["val_accuracy"]):.4f}')
# Out:
# Saved: output_block2\cnn_training_curves.png
# Best epoch        : 19
# Best val loss     : 1.8419
# Best val accuracy : 0.6132

# %% [markdown]
# ## 11. File-Level Evaluation — Score Fusion

# %%
def predict_file_level(model, X_seg, y_file, file_idx, n_classes=N_CLASSES):
    probs   = model.predict(X_seg, verbose=0)
    n_files = len(y_file)
    y_pred_file = np.zeros(n_files, dtype=np.int32)
    for i in range(n_files):
        mask = file_idx == i
        avg_prob = probs[mask].mean(axis=0)
        y_pred_file[i] = np.argmax(avg_prob)
    return y_pred_file, y_file


# We use only original segments 
y_pred_train, y_true_train = predict_file_level(
    model_cnn, X_tr, y_tr_file, file_idx_tr
)
train_acc_file = accuracy_score(y_true_train, y_pred_train)
print(f'File-level train accuracy (score fusion): {train_acc_file:.4f}')
# Out:
# File-level train accuracy (score fusion): 1.0000

# %% [markdown]
# ## 12. Evaluate on Official Test Set

# %%
TEST_PATH = r'C:\Users\34610\Desktop\UNIVERSIDAD\Máster\Integracion tecnologias\Proyecto con augmentation\scenes_stereo_testset'  

test_records = []
for filename in sorted(os.listdir(TEST_PATH)):
    if not filename.endswith('.wav'):
        continue
    label = re.sub(r'\d+$', '', os.path.splitext(filename)[0])
    if label not in CLASS_TO_IDX:
        continue
    test_records.append({
        'filename' : filename,
        'filepath' : os.path.join(TEST_PATH, filename),
        'label'    : label,
        'label_idx': CLASS_TO_IDX[label]
    })

df_test = pd.DataFrame(test_records)
print(f'Test files: {len(df_test)}')

# Test set: sin augmentation
X_test_seg, y_test_seg, y_test_file, file_idx_test = build_segment_dataset(
    df_test, augment=False
)

# Aplicar normalizacion del train aumentado
global_mean = np.load(os.path.join(OUTPUT_DIR, 'cnn_global_mean.npy'))
global_std  = np.load(os.path.join(OUTPUT_DIR, 'cnn_global_std.npy'))
X_test_seg  = (X_test_seg - global_mean) / (global_std + 1e-9)

print(f'Test segments: {X_test_seg.shape}')
# Out:
# Test files: 100
# Building segment dataset: 100%|██████████| 100/100 [00:06<00:00, 14.93it/s]
# Test segments: (1900, 128, 128, 1)

# %%
y_pred_test, y_true_test = predict_file_level(
    model_cnn, X_test_seg, y_test_file, file_idx_test
)

test_acc = accuracy_score(y_true_test, y_pred_test)
test_f1  = f1_score(y_true_test, y_pred_test, average='macro')

print('=' * 60)
print('CNN — OFFICIAL TEST SET RESULTS')
print('=' * 60)
print(f'  File-level accuracy : {test_acc:.4f}')
print(f'  File-level F1 macro : {test_f1:.4f}')
print()
print('Comparison with baselines:')
print(f'  E1 Log-Mel + kNN : 0.4000')
print(f'  E2 Log-Mel + SVM : 0.5900')
print(f'  E3 MFCC + kNN    : 0.6000')
print(f'  E4 MFCC + SVM    : 0.7500  <- previous best')
print(f'  CNN (Log-Mel)    : {test_acc:.4f}  <- this model')
print('=' * 60)

improvement = test_acc - 0.75
if improvement > 0:
    print(f'\nImprovement over best baseline: +{improvement:.4f} ({improvement*100:.1f}%)')
else:
    print(f'\nDifference vs best baseline: {improvement:.4f} ({improvement*100:.1f}%)')
# Out:
# ============================================================
# CNN — OFFICIAL TEST SET RESULTS
# ============================================================
#   File-level accuracy : 0.8000
#   File-level F1 macro : 0.8063
#
# Comparison with baselines:
#   E1 Log-Mel + kNN : 0.4000
#   E2 Log-Mel + SVM : 0.5900
#   E3 MFCC + kNN    : 0.6000
#   E4 MFCC + SVM    : 0.7500  <- previous best
#   CNN (Log-Mel)    : 0.8000  <- this model
# ============================================================
#
# Improvement over best baseline: +0.0500 (5.0%)

# %% [markdown]
# ## 13. Confusion Matrix and Per-Class Analysis

# %%
fig, ax = plt.subplots(figsize=(10, 8))
cm = confusion_matrix(y_true_test, y_pred_test, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=CLASSES)
disp.plot(ax=ax, colorbar=False, cmap='Blues', values_format='.2f')
ax.set_title(f'CNN — Log-Mel (Test Acc: {test_acc:.2f})', fontsize=12, fontweight='bold')
ax.set_xticklabels(CLASSES, rotation=45, ha='right', fontsize=8)
ax.set_yticklabels(CLASSES, fontsize=8)
plt.tight_layout()
out_path = os.path.join(OUTPUT_DIR, 'cnn_confusion_matrix.png')
plt.savefig(out_path, dpi=150, bbox_inches='tight')
plt.show()
print(f'Saved: {out_path}')

print('\nDetailed classification report — CNN (Test Set):')
print(classification_report(y_true_test, y_pred_test, target_names=CLASSES))
# Out:
# Saved: output_block2\cnn_confusion_matrix.png
#
# Detailed classification report — CNN (Test Set):
#                precision    recall  f1-score   support
#
#           bus       1.00      0.90      0.95        10
#    busystreet       0.75      0.90      0.82        10
#        office       0.88      0.70      0.78        10
# openairmarket       0.69      0.90      0.78        10
#          park       0.88      0.70      0.78        10
#   quietstreet       0.50      0.80      0.62        10
#    restaurant       1.00      0.70      0.82        10
#   supermarket       0.88      0.70      0.78        10
#          tube       0.90      0.90      0.90        10
#   tubestation       0.89      0.80      0.84        10
#
#      accuracy                           0.80       100
#     macro avg       0.84      0.80      0.81       100
#  weighted avg       0.84      0.80      0.81       100

# %% [markdown]
# ## 14. Final Comparison — All Models

# %%
models     = ['E1\nLog-Mel+kNN', 'E2\nLog-Mel+SVM', 'E3\nMFCC+kNN',
              'E4\nMFCC+SVM', 'CNN\nLog-Mel']
test_accs  = [0.40, 0.59, 0.60, 0.75, test_acc]
colors_bar = ['#aec6cf', '#aec6cf', '#aec6cf', '#aec6cf', '#2196F3']

fig, ax = plt.subplots(figsize=(12, 5))
bars = ax.bar(models, test_accs, color=colors_bar, edgecolor='black', linewidth=0.7)

for bar, val in zip(bars, test_accs):
    ax.text(bar.get_x() + bar.get_width()/2, bar.get_height() + 0.01,
            f'{val:.2f}', ha='center', va='bottom', fontsize=10, fontweight='bold')

ax.axhline(0.10, color='red',   linestyle='--', linewidth=1.5, label='Random baseline (10%)')
ax.axhline(0.74, color='green', linestyle='--', linewidth=1.5, label='DCASE 2013 system baseline (~74%)')
ax.set_title('Final Comparison — All Models (Official Test Set)',
             fontsize=13, fontweight='bold')
ax.set_ylabel('Test Accuracy', fontsize=11)
ax.set_ylim(0, 1.05)
ax.legend(fontsize=9)
ax.grid(True, axis='y', alpha=0.3)
plt.tight_layout()
out_path = os.path.join(OUTPUT_DIR, 'final_comparison_all_models.png')
plt.savefig(out_path, dpi=150, bbox_inches='tight')
plt.show()
print(f'Saved: {out_path}')
# Out:
# Saved: output_block2\final_comparison_all_models.png

# %% [markdown]
# ## 15. Save CNN Model

# %%
model_path = os.path.join(OUTPUT_DIR, 'cnn_asc_model.keras')
model_cnn.save(model_path)
print(f'CNN model saved: {model_path}')

print('\n' + '=' * 60)
print('BLOCK 4 — FINAL SUMMARY')
print('=' * 60)
print(f'Architecture       : 2D CNN, 4 Conv blocks + GAP')
print(f'Input shape        : ({N_FRAMES}, {N_MELS}, 1)')
print(f'Segment duration   : {N_FRAMES * HOP_LEN / SR:.1f}s')
print(f'Segments per file  : ~{len(X_tr) // len(df_train)}')
print(f'Total train segs   : {len(X_tr)}')
print(f'Epochs trained     : {len(history.history["loss"])}')
print(f'Test accuracy      : {test_acc:.4f}')
print(f'Test F1 macro      : {test_f1:.4f}')
print(f'Best baseline      : 0.7500 (E4 MFCC+SVM)')
print(f'Improvement        : {test_acc - 0.75:+.4f}')
print('=' * 60)
# Out:
# CNN model saved: output_block2\cnn_asc_model.keras
#
# ============================================================
# BLOCK 4 — FINAL SUMMARY
# ============================================================
# Architecture       : 2D CNN, 4 Conv blocks + GAP
# Input shape        : (128, 128, 1)
# Segment duration   : 3.0s
# Segments per file  : ~60
# Total train segs   : 6080
# Epochs trained     : 39
# Test accuracy      : 0.8000
# Test F1 macro      : 0.8063
# Best baseline      : 0.7500 (E4 MFCC+SVM)
# Improvement        : +0.0500
# ============================================================
